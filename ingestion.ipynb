# %%
from graph_builder import FolktaleGraphBuilder
from utils.loader import load_json
from schemas.folktale import Folktale
from neo4j_manager import Neo4jManager
from tqdm import tqdm
import os

# %%
out_dir = "./out"

# %%
folktales = []
for file in os.listdir(out_dir):
	path = os.path.join(out_dir, file)
	folktale = load_json(path)
	folktales.append(Folktale(**folktale))

# %%
neo4j = Neo4jManager()

# %%
graph_builder = FolktaleGraphBuilder(neo4j)
graph_builder.clear_database()
graph_builder.setup()

# %%
for folktale in tqdm(folktales):
	graph_builder.add_folktale(folktale)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# ['Folktale: Momotaro\n\nObject: magic peach\nType: magical_object\n\nDescription:\nThe peach that bursts in two to reveal a baby boy inside.\n', "Folktale: Momotaro\n\nObject: kimi-dango wallet\nType: crafted_object\n\nDescription:\nA wallet containing millet dumplings given to Momotaro by his mother for his journey to the Ogres' Island.\n"]
# ['Folktale: Momotaro\n\nPlace: the mountains\nType: mountain\n\nDescription:\nwhere the old man went to gather sticks\n', 'Folktale: Momotaro\n\nPlace: the stream\nType: river\n\nDescription:\nwhere the old woman washed clothes and found a peach\n', "Folktale: Momotaro\n\nPlace: the Ogres' Island castle\nType: castle\n\nDescription:\na fortified residence where Momotaro fought the Ogres\n", 'Folktale: Momotaro\n\nPlace: their village\nType: village\n\nDescription:\nwhere Momotaro lived with his adoptive parents\n', 'Folktale: Momotaro\n\nPlace: the country-side\nType: town\n\nDescription:\na medium-sized settlement larger than a village, where Momotaro was known\n']
#  50%|█████     | 1/2 [00:05<00:05,  5.28s/it]
# ["Folktale: The Birdcatcher\n\nObject: crow\nType: magical_object\n\nDescription:\nThe birdcatcher's magical crow helps him find the mother of the nightingales and later becomes a key figure in his transformation into a young man.\n", "Folktale: The Birdcatcher\n\nObject: nightingales\nType: natural_object\n\nDescription:\nTheir singing attracts people to the mosque, leading to the emperor's discovery of them and their mother.\n", 'Folktale: The Birdcatcher\n\nObject: cage\nType: crafted_object\n\nDescription:\nThe birdcatcher uses a cage to capture the mother of the nightingales.\n', 'Folktale: The Birdcatcher\n\nObject: oil\nType: natural_object\n\nDescription:\nThe birdcatcher pours oil into the sea, causing a violent agitation that allows the crow to find the missing ring fragment.\n', "Folktale: The Birdcatcher\n\nObject: boat\nType: crafted_object\n\nDescription:\nThe birdcatcher uses the boat to transport people and goods, including the nightingales' mother.\n", 'Folktale: The Birdcatcher\n\nObject: ring fragment\nType: magical_object\n\nDescription:\nThe crow finds this piece of a ring in the sea, which is crucial to reuniting it with its other half.\n']
# ['Folktale: The Birdcatcher\n\nPlace: Constantinople\nType: city\n\nDescription:\nA large city near where the birdcatcher lived.\n', "Folktale: The Birdcatcher\n\nPlace: The Emperor's Palace\nType: palace\n\nDescription:\nThe emperor's official residence, located on a quay.\n", "Folktale: The Birdcatcher\n\nPlace: The Birdcacher's Home\nType: house\n\nDescription:\nThe birdcatcher's family home, where he and his wife lived with their children.\n", 'Folktale: The Birdcatcher\n\nPlace: The Village Where the Crow Was Found\nType: village\n\nDescription:\nA rural settlement near where the crow was first encountered.\n', 'Folktale: The Birdcatcher\n\nPlace: The Town Near the Mosque\nType: town\n\nDescription:\nA medium-sized settlement located near a grand mosque.\n']
# 100%|██████████| 2/2 [00:10<00:00,  5.32s/it]

# %%
graph_builder.find_loose_entities()
# Out:
# []

# %%
graph_builder.create_vector_databases()
# Out:
# El índice vectorial 'event_embeddings' ya existe. Saltando.
# El índice vectorial 'agent_embeddings' ya existe. Saltando.
# El índice vectorial 'place_embeddings' ya existe. Saltando.
# El índice vectorial 'object_embeddings' ya existe. Saltando.

# %%
neo4j.close()
