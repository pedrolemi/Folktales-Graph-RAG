# %%
from models.object import Object, ObjectLLM, ObjectType

object_llm = ObjectLLM(
    type=ObjectType.CRAFTED_OBJECT,
    name="test"
)

print(object_llm)

object = Object.from_llm(object_llm)
print(object)
# Out:
# type=<ObjectType.CRAFTED_OBJECT: 'crafted_object'> name='test'
# type=<ObjectType.CRAFTED_OBJECT: 'crafted_object'> name='test' id='object_b7fadf0cd2f94c2b90cf63ba57946dad'
